# %% [markdown]
# # 04_SHAP (SHapley Additive exPlanations) - Kernel SHAP
# ### [shap](https://github.com/slundberg/shap): A game theoretic approach to explain the output of any machine learning model.
#
# <img src="slide_image/shap_header.svg" width=720/>

# %%
# !pip install imblearn shap -q

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score, accuracy_score, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from data import Cervical_DataLoader, Bike_DataLoader

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Classification Problem

# %% [markdown]
# ### Explore the dataset - Risk Factors for Cervical Cancer
# #### Features
# - Age: 年齡（歲）
# - Number of sexual partners: 性伴侶數量
# - First sexual intercourse: 首次性行為（歲）
# - Num of pregnancies: 懷孕次數
# - Smokes: 吸菸與否
# - Smokes (years): 煙齡（年）
# - Hormonal Contraceptive: 是否服用激素避孕藥
# - Hormonal Contraceptives (years): 服用激素避孕藥的時間（年）
# - IUD: 是否有宮內節育器
# - IUD (years): 使用宮內節育器 (IUD) 的年數
# - STDs: 是否患有性傳播疾病
# - STDs (number): 患有幾個性傳播疾病
# - STDs: Number of diagnosis: 性病診斷次數
# - STDs: Time since first diagnosis: 第一次性病診斷後到現在的時間
# - STDs: Time since last diagnosis: 上次性病診斷到現在的時間
#
# #### Labels
# - Biopsy: 健康與否

# %%
# Load and preprocess data
data_loader = Cervical_DataLoader()
data_loader.load_dataset()
data_loader.preprocess_data()

# Split the data for evaluation
X_train, X_test, y_train, y_test = data_loader.get_data_split()
print(X_train.shape)
print(X_test.shape)
# Out:
# (686, 17)
# (172, 17)

# %%
# Oversample the train data
X_train, y_train = data_loader.oversample(X_train, y_train)
print("After oversampling:", X_train.shape)
# Out:
# After oversampling: (1286, 17)

# %% [markdown]
# ### Classification Moldes
# - Logistic Regression
# - Decision Tree for Classification
# - XGB for Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %% [markdown]
# #### Logistic Regression

# %%
# Fit logistic regression model
lr = LogisticRegression(random_state=2022, penalty='l1', solver='liblinear')
lr.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate logistic regression model
y_pred = lr.predict(X_test.values)
print(f"F1 Score: {round(f1_score(y_test, y_pred, average='macro'), 2)}")
print(f"Accuracy: {round(accuracy_score(y_test, y_pred), 2)}")
# Out:
# Training finished.
# F1 Score: 0.48
# Accuracy: 0.7

# %% [markdown]
# ###  Kernel SHAP to explain Logistic Regression

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=lr.predict_proba, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 1286 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/172 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values[0].shape}')
# Out:
# length of SHAP values: 2
# Shape of each element: (172, 17)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values[1], X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {lr.predict_proba(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value[0], shap_values[0][0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: [0.50617767 0.49382233]
# <div id='iYYVUKQ1Y35PI1T0JQX51'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.
# %% [markdown]
# #### Decision Tree for Classification

# %%
# Fit decision tree for classification model
ct = DecisionTreeClassifier(random_state=2022)
ct.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate decision tree for classification model
y_pred = ct.predict(X_test.values)
print(f"F1 Score: {round(f1_score(y_test, y_pred, average='macro'), 2)}")
print(f"Accuracy: {round(accuracy_score(y_test, y_pred), 2)}")
# Out:
# Training finished.
# F1 Score: 0.54
# Accuracy: 0.87

# %% [markdown]
# ###  Kernel SHAP to explain Decision Tree

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=ct.predict_proba, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 1286 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/172 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values[0].shape}')
# Out:
# length of SHAP values: 2
# Shape of each element: (172, 17)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values[1], X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {ct.predict_proba(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value[0], shap_values[0][0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: [1. 0.]
# <div id='iICFQW8U17UWWE5K6PTKD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49999999999999606, "outValue": 1.0, "link": "identity", "featureNames": ["Age", "Number.of.sexual.partners", "First.sexual.intercourse", "Num.of.pregnancies", "Smokes..years.", "Hormonal.Contraceptives..years.", "IUD..years.", "STDs..number.", "STDs..Number.of.diagnosis", "Smokes_0", "Smokes_1", "Hormonal.Contraceptives_0", "Hormonal.Contraceptives_1", "IUD_0", "IUD_1", "STDs_0", "STDs_1"], "features": {"0": {"effect": 0.037075753762305874, "value": 27.0}, "1": {"effect": 0.034610784855562626, "value": 1.0}, "2": {"effect": 0.220344788955614, "value": 16.0}, "3": {"effect": 0.010499158640825207, "value": 2.0}, "4": {"effect": 0.012978082372572836, "value": 0.0}, "5": {"effect": -0.05601288570567442, "value": 7.0}, "11": {"effect": 0.22633641068996835, "value": 0.0}, "12": {"effect": 0.004313254672182021, "value": 1.0}, "16": {"effect": 0.00985465175664757, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iICFQW8U17UWWE5K6PTKD')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value[1], shap_values[1][0,:], X_test.iloc[0,:])
# Out:
# <div id='iP3BT5CO4K6VKH16NKT87'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49999999999999606, "outValue": 0.0, "link": "identity", "featureNames": ["Age", "Number.of.sexual.partners", "First.sexual.intercourse", "Num.of.pregnancies", "Smokes..years.", "Hormonal.Contraceptives..years.", "IUD..years.", "STDs..number.", "STDs..Number.of.diagnosis", "Smokes_0", "Smokes_1", "Hormonal.Contraceptives_0", "Hormonal.Contraceptives_1", "IUD_0", "IUD_1", "STDs_0", "STDs_1"], "features": {"0": {"effect": -0.03707575376230532, "value": 27.0}, "1": {"effect": -0.03461078485556429, "value": 1.0}, "2": {"effect": -0.22034478895560652, "value": 16.0}, "3": {"effect": -0.01049915864082726, "value": 2.0}, "4": {"effect": -0.012978082372574723, "value": 0.0}, "5": {"effect": 0.056012885705670756, "value": 7.0}, "11": {"effect": -0.2263364106899574, "value": 0.0}, "12": {"effect": -0.004313254672183589, "value": 1.0}, "16": {"effect": -0.009854651756647681, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iP3BT5CO4K6VKH16NKT87')
#   );
# </script>

# %% [markdown]
# Explain all the predictions in the test set

# %%
shap.force_plot(explainer.expected_value[1], shap_values[1], X_test)
# Out:
# <div id='iEHRYA8PVX22TU7BLS2MV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49999999999999606, "link": "identity", "featureNames": ["Age", "Number.of.sexual.partners", "First.sexual.intercourse", "Num.of.pregnancies", "Smokes..years.", "Hormonal.Contraceptives..years.", "IUD..years.", "STDs..number.", "STDs..Number.of.diagnosis", "Smokes_0", "Smokes_1", "Hormonal.Contraceptives_0", "Hormonal.Contraceptives_1", "IUD_0", "IUD_1", "STDs_0", "STDs_1"], "explanations": [{"outValue": 0.0, "simIndex": 87.0, "features": {"0": {"effect": -0.03707575376230532, "value": 27.0}, "1": {"effect": -0.03461078485556429, "value": 1.0}, "2": {"effect": -0.22034478895560652, "value": 16.0}, "3": {"effect": -0.01049915864082726, "value": 2.0}, "4": {"effect": -0.012978082372574723, "value": 0.0}, "5": {"effect": 0.056012885705670756, "value": 7.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": -0.2263364106899574, "value": 0.0}, "12": {"effect": -0.004313254672183589, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": 0.0, "value": 1.0}, "16": {"effect": -0.009854651756647681, "value": 0.0}}}, {"outValue": 0.0, "simIndex": 140.0, "features": {"0": {"effect": -0.004449855263115185, "value": 17.0}, "1": {"effect": -0.06967148076679494, "value": 2.0}, "2": {"effect": -0.12320229174615371, "value": 12.0}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": -0.017953789298913336, "value": 0.0}, "5": {"effect": -0.22023267589255768, "value": 0.0}, "6": {"effect": -0.013003779755314637, "value": 0.0}, "7": {"effect": -0.013224937049615693, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.015608013365249807, "value": 1.0}, "10": {"effect": -0.008033745439056716, "value": 0.0}, "11": {"effect": -0.02358515838206071, "value": 0.0}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": -0.006989627441705282, "value": 1.0}, "16": {"effect": -0.01526067232995798, "value": 0.0}}}, {"outValue": 0.0, "simIndex": 148.0, "features": {"0": {"effect": -0.029812504591545302, "value": 31.0}, "1": {"effect": -0.08015376691612675, "value": 2.0}, "2": {"effect": -0.07005361911970942, "value": 17.0}, "3": {"effect": 0.0, "value": 3.0}, "4": {"effect": -0.0019785091502876884, "value": 0.0}, "5": {"effect": -0.1606525911315753, "value": 0.0}, "6": {"effect": -0.023520614474168033, "value": 0.0}, "7": {"effect": -0.0041701731656303975, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": -0.04639857811230619, "value": 0.0}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": 0.0, "value": 1.0}, "16": {"effect": -0.083259643338647, "value": 0.0}}}, {"outValue": -5.551115123125783e-17, "simIndex": 28.0, "features": {"0": {"effect": -0.02986230694324389, "value": 23.0}, "1": {"effect": -0.09326604077056447, "value": 1.0}, "2": {"effect": -0.0364661993221352, "value": 19.0}, "3": {"effect": 0.0, "value": 1.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": -0.4544950086736552, "value": 0.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.16069456075383798, "value": 1.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": -0.013545662400671649, "value": 1.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": 0.0, "value": 1.0}, "16": {"effect": -0.03305934264356364, "value": 0.0}}}, {"outValue": 0.0, "simIndex": 93.0, "features": {"0": {"effect": -0.043729847361950736, "value": 21.0}, "1": {"effect": 0.0, "value": 1.0}, "2": {"effect": - ...

# %% [markdown]
# #### XGB for Classification

# %%
# Fit XGB for classification model
xgbc = XGBClassifier(random_state=2022)
xgbc.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate XGB for classification model
y_pred = xgbc.predict(X_test.values)
print(f"F1 Score: {round(f1_score(y_test, y_pred, average='macro'), 2)}")
print(f"Accuracy: {round(accuracy_score(y_test, y_pred), 2)}")
# Out:
# Training finished.
# F1 Score: 0.55
# Accuracy: 0.92

# %% [markdown]
# ###  Kernel SHAP to explain XGB for classification model

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=xgbc.predict_proba, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 1286 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/172 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values[0].shape}')
# Out:
# length of SHAP values: 2
# Shape of each element: (172, 17)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values[1], X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {xgbc.predict_proba(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value[0], shap_values[0][0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: [0.9139003  0.08609968]
# <div id='iLMUBPANFBEF1XP756H1H'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.49995861046050977, "outValue": 0.9139003157615662, "link": "identity", "featureNames": ["Age", "Number.of.sexual.partners", "First.sexual.intercourse", "Num.of.pregnancies", "Smokes..years.", "Hormonal.Contraceptives..years.", "IUD..years.", "STDs..number.", "STDs..Number.of.diagnosis", "Smokes_0", "Smokes_1", "Hormonal.Contraceptives_0", "Hormonal.Contraceptives_1", "IUD_0", "IUD_1", "STDs_0", "STDs_1"], "features": {"0": {"effect": 0.013108871489698526, "value": 27.0}, "1": {"effect": 0.11294704805751041, "value": 1.0}, "2": {"effect": 0.09903227874772669, "value": 16.0}, "3": {"effect": 0.06051531624135392, "value": 2.0}, "4": {"effect": 0.006952950493040788, "value": 0.0}, "5": {"effect": -0.015289493291650552, "value": 7.0}, "6": {"effect": 0.019332064816036637, "value": 0.0}, "7": {"effect": 0.013629254036152005, "value": 0.0}, "8": {"effect": 0.016090832406288835, "value": 0.0}, "9": {"effect": -0.0043416884808665235, "value": 1.0}, "10": {"effect": -0.004818230640908569, "value": 0.0}, "11": {"effect": 0.11285197391630819, "value": 0.0}, "12": {"effect": -0.007092712739470208, "value": 1.0}, "13": {"effect": -0.005868500964496981, "value": 1.0}, "14": {"effect": 0.01026789617141588, "value": 0.0}, "15": {"effect": -0.006985186769770391, "value": 1.0}, "16": {"effect": -0.006390968187312274, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iLMUBPANFBEF1XP756H1H')
#   );
# </script>

# %%
shap.force_plot(explainer.expected_value[1], shap_values[1][0,:], X_test.iloc[0,:])
# Out:
# <div id='i2OVYGN47PTNBK4W2CQ0P'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.5000413894000816, "outValue": 0.0860996842384339, "link": "identity", "featureNames": ["Age", "Number.of.sexual.partners", "First.sexual.intercourse", "Num.of.pregnancies", "Smokes..years.", "Hormonal.Contraceptives..years.", "IUD..years.", "STDs..number.", "STDs..Number.of.diagnosis", "Smokes_0", "Smokes_1", "Hormonal.Contraceptives_0", "Hormonal.Contraceptives_1", "IUD_0", "IUD_1", "STDs_0", "STDs_1"], "features": {"0": {"effect": -0.013108871272017542, "value": 27.0}, "1": {"effect": -0.11294704937041847, "value": 1.0}, "2": {"effect": -0.09903227994038699, "value": 16.0}, "3": {"effect": -0.060515314636423956, "value": 2.0}, "4": {"effect": -0.00695294977826344, "value": 0.0}, "5": {"effect": 0.015289493207448435, "value": 7.0}, "6": {"effect": -0.019332065111123273, "value": 0.0}, "7": {"effect": -0.013629254173874839, "value": 0.0}, "8": {"effect": -0.01609083268159045,
"value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": -0.043013243158911973, "value": 0.0}, "12": {"effect": 0.0, "value": 1.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {"effect": -0.0007239691515823488, "value": 0.0}, "15": {"effect": 0.007182240311442267, "value": 1.0}, "16": {"effect": 0.0, "value": 0.0}}}, {"outValue": 0.028356019407510757, "simIndex": 155.0, "features": {"0": {"effect": -0.07624255748404485, "value": 23.0}, "1": {"effect": -0.08954159611330192, "value": 1.0}, "2": {"effect": -0.014780797610628782, "value": 19.0}, "3": {"effect": -0.05826600443826757, "value": 1.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": -0.26966793705600095, "value": 0.0}, "6": {"effect": -0.007382399413907947, "value": 0.0}, "7": {"effect": -0.04426790829666677, "value": 0.0}, "8": {"effect": -0.019595937375998296, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.10805976779624626, "value": 1.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": 0.0, "value": 1.0}, "14": {" ...

# %% [markdown]
# ## Regression Problem

# %% [markdown]
# ### Explore the dataset - Bike Rentals
# #### Features
# - season: 季節，包含春、夏、秋、冬
# - yr: 年份，2011 年或 2012 年
# - mnth: 月份，1~12 月
# - holiday: 當天是否為假期
# - weekday: 星期幾
# - workingday: 當天是否為工作日
# - weathersit: 那天的天氣情況是下面幾種狀況的其中一個
#     - GOOD: 晴朗
#     - MISTY: 有霧、有雲
#     - RAIN/SNOW/STORM: 下雨、下雪、暴風
# - temp: 溫度（攝氏度）
# - hum: 相對濕度百分比（0~100%）
# - windspeed: 風速(km/h)
# - days_since_2011: 自 2011 年 1 月 1 日（數據集中的第一天）起的天數。引入此特性是為了考慮隨時間變化的趨勢。
#
# #### Labels
# - cnt: 自行車租賃的數量，也就是此回歸任務的預測目標

# %%
# Load and preprocess data
data_loader = Bike_DataLoader()
data_loader.load_dataset()
data_loader.preprocess_data()
data_loader.data

# Split the data for evaluation
X_train, X_test, y_train, y_test = data_loader.get_data_split()
print(X_train.shape)
print(X_test.shape)
# Out:
# (584, 36)
# (147, 36)

# %% [markdown]
# ### Regression Moldes
# - Linear Regression
# - Decision Tree for Regression
# - XGB for Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %% [markdown]
# #### Linear Regression

# %%
# Fit linear regression model
lr = LinearRegression()
lr.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate linear regression model
y_pred = lr.predict(X_test.values)
print(f"Root Mean Squared Error: {round(mean_squared_error(y_test, y_pred)**(1/2), 2)}")
print(f"R2: {round(r2_score(y_test, y_pred), 2)}")
# Out:
# Training finished.
# Root Mean Squared Error: 794.04
# R2: 0.81

# %% [markdown]
# ###  Kernel SHAP to explain Linear Regression

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=lr.predict, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 584 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/147 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values.shape}')
# Out:
# length of SHAP values: 147
# Shape of each element: (36,)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {lr.predict(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: 6694.3386815483655
# <div id='i55PE6308N1FXPVLGT2KQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 4479.458904109588, "outValue": 6694.338681548365, "link": "identity", "featureNames": ["temp", "hum", "windspeed", "days_since_2011", "season_FALL", "season_SPRING", "season_SUMMER", "season_WINTER", "yr_2011", "yr_2012", "mnth_APR", "mnth_AUG", "mnth_DEC", "mnth_FEB", "mnth_JAN", "mnth_JUL", "mnth_JUN", "mnth_MAR", "mnth_MAY", "mnth_NOV", "mnth_OCT", "mnth_SEP", "holiday_HOLIDAY", "holiday_NO HOLIDAY", "weekday_FRI", "weekday_MON", "weekday_SAT", "weekday_SUN", "weekday_THU", "weekday_TUE", "weekday_WED", "workingday_NO WORKING DAY", "workingday_WORKING DAY", "weathersit_GOOD", "weathersit_MISTY", "weathersit_RAIN/SNOW/STORM"], "features": {"0": {"effect": 445.5218235670891, "value": 19.416651}, "1": {"effect": 121.74111369317961, "value": 54.9167}, "2": {"effect": 6.5252344567106775, "value": 12.499654}, "3": {"effect": -1069.6390324545864, "value": 518.0}, "4": {"effect": -186.7803654827817, "value": 0.0}, "5": {"effect": 51.39037319886347, "value": 1.0}, "6": {"effect": 0.9742437864485964, "value": 0.0}, "7": {"effect": 220.94104455151182, "value": 0.0}, "8": {"effect": 1125.7917605016792, "value": 0.0}, "9": {"effect": 1125.791760501671, "value": 1.0}, "10": {"effect": 37.52133684728142, "value": 0.0}, "11": {"effect": -23.061829877355194, "value": 0.0}, "12": {"effect": -61.97503834730014, "value": 0.0}, "13": {"effect": 90.33259180136702, "value": 0.0}, "14": {"effect": 122.16414917910242, "value": 0.0}, "15": {"effect": 24.853218804381413, "value": 0.0}, "16": {"effect": -55.438304639132184, "value": 1.0}, "17": {"effect": 39.76428705870603, "value": 0.0}, "18": {"effect": -0.830193319643513, "value": 0.0}, "19": {"effect": -37.87871643168637, "value": 0.0}, "20": {"effect": -75.77136298819096, "value": 0.0}, "21": {"effect": -94.42273945517081, "value": 0.0}, "22": {"effect": 6.2603008950159165, "value": 0.0}, "23": {"effect": 6.260300895002729, "value": 1.0}, "24": {"effect": -6.0285557963834435, "value": 0.0}, "25": {
}, "27": {"effect": 23.817736746570517, "value": 0.0}, "28": {"effect": -1.5246725368915577, "value": 0.0}, "29": {"effect": 3.6118209034862048, "value": 0.0}, "30": {"effect": 2.2257152718452744, "value": 0.0}, "31": {"effect": -62.875799496733634, "value": 1.0}, "32": {"effect": -62.87579949676001, "value": 0.0}, "33": {"effect": 324.7345389530292, "value": 1.0}, "34": {"effect": -135.1556322115939, "value": 0.0}, "35": {"effect": 38.793999502727274, "value": 0.0}}}, {"outValue": 3086.6399215834535, "simIndex": 142.0, "features": {"0": {"effect": -575.0954011090676, "value": 9.533021000000002}, "1": {"effect": -131.93851032115185, "value": 71.6087}, "2": {"effect": -456.6677038591469, "value": 23.39171}, "3": {"effect": -127.97158041702028, "value": 381.0}, "4": {"effect": -186.78036548279806, "value": 0.0}, "5": {"effect": -16.51002939871546, "value": 0.0}, "6": {"effect": 0.9742437864533713, "value": 0.0}, "7": {"effect": -627.9377055674461, "value": 1.0}, "8": {"effect": 1125.7917605016585, "value": 0.0}, "9": {"effect": 1125.791760501674, "value": 1.0}, "10": {"effect": 37.52133684726755, "value": 0.0}, "11": {"effect": -23.061829877359173, "value": 0.0}, "12": {"effect": -61.97503834728241, "value": 0.0}, "13": {"effect": 90.3325918013802, "value": 0.0}, "14": {"effect": -1223.9464757379328, "value": 1.0}, "15": {"effect": 24.853218804397784, "value": 0.0}, "16": {"effect": 4.406371718077935, "value": 0.0}, "17": {"effect": 39.764287058717855, "value": 0.0}, "18": {"effect": -0.8301933196430582, "value": 0.0}, "19": {"effect": -37.87871643167773, "value": 0.0}, "20": {"effect": -75.77136298817277, "value": 0.0}, "21": {"effect": -94.42273945515035, "value": 0.0}, "22": {"effect": 6.26030089499227, "value": 0.0}, "23": {"effect": 6.260300894993634, "value": 1.0}, "24": {"e ...

# %% [markdown]
# #### Decision Tree for Regression

# %%
# Fit decision tree for regression model
rt = DecisionTreeRegressor(random_state=2022)
rt.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate decision tree for classification model
y_pred = rt.predict(X_test.values)
print(f"Root Mean Squared Error: {round(mean_squared_error(y_test, y_pred)**(1/2), 2)}")
print(f"R2: {round(r2_score(y_test, y_pred), 2)}")
# Out:
# Training finished.
# Root Mean Squared Error: 920.7
# R2: 0.74

# %% [markdown]
# ###  Kernel SHAP to explain Decision Tree

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=rt.predict, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 584 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/147 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values[0].shape}')
# Out:
# length of SHAP values: 147
# Shape of each element: (36,)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {rt.predict(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: 7458.0
# <div id='iG78KU6PSOWP16TS6UVK7'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 4479.458904109589, "outValue": 7458.0, "link": "identity", "featureNames": ["temp", "hum", "windspeed", "days_since_2011", "season_FALL", "season_SPRING", "season_SUMMER", "season_WINTER", "yr_2011", "yr_2012", "mnth_APR", "mnth_AUG", "mnth_DEC", "mnth_FEB", "mnth_JAN", "mnth_JUL", "mnth_JUN", "mnth_MAR", "mnth_MAY", "mnth_NOV", "mnth_OCT", "mnth_SEP", "holiday_HOLIDAY", "holiday_NO HOLIDAY", "weekday_FRI", "weekday_MON", "weekday_SAT", "weekday_SUN", "weekday_THU", "weekday_TUE", "weekday_WED", "workingday_NO WORKING DAY", "workingday_WORKING DAY", "weathersit_GOOD", "weathersit_MISTY", "weathersit_RAIN/SNOW/STORM"], "features": {"0": {"effect": 784.4886486165669, "value": 19.416651}, "1": {"effect": 410.7287021009248, "value": 54.9167}, "2": {"effect": 43.56160862529319, "value": 12.499654}, "3": {"effect": 1503.9112402152616, "value": 518.0}, "15": {"effect": 21.03845697661562, "value": 0.0}, "16": {"effect": 41.14844846396409, "value": 1.0}, "20": {"effect": 31.111498985949197, "value": 0.0}, "21": {"effect": 12.829218572110221, "value": 0.0}, "26": {"effect": 26.152489110204215, "value": 1.0}, "27": {"effect": 32.216019865923954, "value": 0.0}, "34": {"effect": 18.66877039778683, "value": 0.0}, "35": {"effect": 52.68599395981073, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iG78KU6PSOWP16TS6UVK7')
#   );
# </script>

# %% [markdown]
# Explain all the predictions in the test set

# %%
shap.force_plot(explainer.expected_value, shap_values, X_test)
# Out:
# <div id='i2DGBG4738V7T8JWYPIC2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 4479.458904109589, "link": "identity", "featureNames": ["temp", "hum", "windspeed", "days_since_2011", "season_FALL", "season_SPRING", "season_SUMMER", "season_WINTER", "yr_2011", "yr_2012", "mnth_APR", "mnth_AUG", "mnth_DEC", "mnth_FEB", "mnth_JAN", "mnth_JUL", "mnth_JUN", "mnth_MAR", "mnth_MAY", "mnth_NOV", "mnth_OCT", "mnth_SEP", "holiday_HOLIDAY", "holiday_NO HOLIDAY", "weekday_FRI", "weekday_MON", "weekday_SAT", "weekday_SUN", "weekday_THU", "weekday_TUE", "weekday_WED", "workingday_NO WORKING DAY", "workingday_WORKING DAY", "weathersit_GOOD", "weathersit_MISTY", "weathersit_RAIN/SNOW/STORM"], "explanations": [{"outValue": 7458.0, "simIndex": 30.0, "features": {"0": {"effect": 784.4886486165669, "value": 19.416651}, "1": {"effect": 410.7287021009248, "value": 54.9167}, "2": {"effect": 43.56160862529319, "value": 12.499654}, "3": {"effect": 1503.9112402152616, "value": 518.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": 0.0, "value": 1.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": 0.0, "value": 0.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": 21.03845697661562, "value": 0.0}, "16": {"effect": 41.14844846396409, "value": 1.0}, "17": {"effect": 0.0, "value": 0.0}, "18": {"effect": 0.0, "value": 0.0}, "19": {"effect": 0.0, "value": 0.0}, "20": {"effect": 31.111498985949197, "value": 0.0}, "21": {"effect": 12.829218572110221, "value": 0.0}, "22": {"effect": 0.0, "value": 0.0}, "23": {"effect": 0.0, "value": 1.0}, "24": {"effect": 0.0, "value": 0.0}, "25": {"effect": 0.0, "value": 0.0}, "26": {"effect": 26.152489110204215, "value": 1.0}, "27": {"effect": 32.216019865923954, "value": 0.0}, "28": {"effect": 0.0, "value": 0.0}, "29": {"effect": 0.0, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 1.0}, "32": {"effect": 0.0, "value": 0.0}, "33": {"effect": 0.0, "value": 1.0}, "34": {"effect": 18.66877039778683, "value": 0.0}, "35": {"effect": 52.68599395981073, "value": 0.0}}}, {"outValue": 1162.0, "simIndex": 77.0, "features": {"0": {"effect": -970.1559664731049, "value": 9.533021000000002}, "1": {"effect": -1003.6853769604932, "value": 71.6087}, "2": {"effect": -445.91532286083066, "value": 23.39171}, "3": {"effect": -674.1675848719456, "value": 381.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": 0.0, "value": 0.0}, "6": {"effect": -123.25971498411377, "value": 0.0}, "7": {"effect": 0.0, "value": 1.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": 0.0, "value": 0.0}, "14": {"effect": 0.0, "value": 1.0}, "15": {"effect": 0.0, "value": 0.0}, "16": {"effect": 0.0, "value": 0.0}, "17": {"effect": 0.0, "value": 0.0}, "18": {"effect": 0.0, "value": 0.0}, "19": {"effect": 0.0, "value": 0.0}, "20": {"effect": 0.0, "value": 0.0}, "21": {"effect": -55.621705628348536, "value": 0.0}, "22": {"effect": 0.0, "value": 0.0}, "23": {"effect": 0.0, "value": 1.0}, "24": {"effect": -44.65323233075196, "value": 0.0}, "25": {"effect": 0.0, "value": 0.0}, "26": {"effect": 0.0, "value": 0.0}, "27": {"effect": 0.0, "value": 0.0}, "28": {"effect": 0.0, "value": 0.0}, "29": {"effect": 0.0, "value": 1.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.0, "value": 1.0}, "33": {"effect": 0.0, "value": 0.0}, "34": {"effect": 0.0, "value": 1.0}, "35": {"effect": 0.0, "value": 0.0}}}, {"outValue": 1913.0, "simIndex": 138.0, "features": {"0": {"effect": -1065.9944976890847, "value": 4.506089}, "1": {"effect": 201.79893911286172, "value": 31.4348}, "2": {"effect": -77.89375066893672, ...

# %% [markdown]
# #### XGB for Regression

# %%
# Fit XGB for regression model
xgbr = XGBRegressor(random_state=2022)
xgbr.fit(X_train.values, y_train.values)
print("Training finished.")

# Evaluate XGB for regression model
y_pred = xgbr.predict(X_test.values)
print(f"Root Mean Squared Error: {round(mean_squared_error(y_test, y_pred)**(1/2), 2)}")
print(f"R2: {round(r2_score(y_test, y_pred), 2)}")
# Out:
# [10:20:26] WARNING: /opt/conda/conda-bld/xgboost_1560800456086/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Training finished.
# Root Mean Squared Error: 613.53
# R2: 0.88

# %% [markdown]
# ###  Kernel SHAP to explain XGB for regression model

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# use Kernel SHAP to explain test set predictions
explainer = shap.KernelExplainer(model=xgbr.predict, data=X_train)
shap_values = explainer.shap_values(X=X_test, nsamples=100)
# Out:
# Using 584 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/147 [00:00<?, ?it/s]

# %%
print(f'length of SHAP values: {len(shap_values)}')
print(f'Shape of each element: {shap_values.shape}')
# Out:
# length of SHAP values: 147
# Shape of each element: (147, 36)

# %% [markdown]
# #### Global interpretability
# - 點的顏色: Feature value 的大小，越紅越大、越藍越小
# - X 軸: 該點對於 shap value 的影響，也就是對預測值的影響。
# - Y 軸: 各個 features

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# #### Local interpretability

# %% [markdown]
# Explain a single prediction from the test set

# %%
# plot the SHAP values for output of the first instance
print(f'Prediction for 1st sample in X_test: {xgbr.predict(X_test.iloc[[0], :].values)[0]}')
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:])
# Out:
# Prediction for 1st sample in X_test: 7319.6357421875
# <div id='iFO918L56Y5GBSEPWD9GW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 4479.9888219310815, "outValue": 7319.6357421875, "link": "identity", "featureNames": ["temp", "hum", "windspeed", "days_since_2011", "season_FALL", "season_SPRING", "season_SUMMER", "season_WINTER", "yr_2011", "yr_2012", "mnth_APR", "mnth_AUG", "mnth_DEC", "mnth_FEB", "mnth_JAN", "mnth_JUL", "mnth_JUN", "mnth_MAR", "mnth_MAY", "mnth_NOV", "mnth_OCT", "mnth_SEP", "holiday_HOLIDAY", "holiday_NO HOLIDAY", "weekday_FRI", "weekday_MON", "weekday_SAT", "weekday_SUN", "weekday_THU", "weekday_TUE", "weekday_WED", "workingday_NO WORKING DAY", "workingday_WORKING DAY", "weathersit_GOOD", "weathersit_MISTY", "weathersit_RAIN/SNOW/STORM"], "features": {"0": {"effect": 909.6157117279755, "value": 19.416651}, "1": {"effect": 294.9913591033539, "value": 54.9167}, "2": {"effect": 45.097664677571856, "value": 12.499654}, "3": {"effect": 1277.8783907454633, "value": 518.0}, "22": {"effect": 1.0549084268637898, "value": 0.0}, "25": {"effect": -0.5125939953643694, "value": 0.0}, "26": {"effect": 138.04513550872826, "value": 1.0}, "27": {"effect": 24.049363490856194, "value": 0.0}, "33": {"effect": 128.97261990732886, "value": 1.0}, "35": {"effect": 20.454360663641637, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iFO918L56Y5GBSEPWD9GW')
#   );
# </script>

# %% [markdown]
# Explain all the predictions in the test set

# %%
shap.force_plot(explainer.expected_value, shap_values, X_test)
# Out:
# <div id='iCDV1Y3EZKOOJAKGXTK45'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 4479.9888219310815, "link": "identity", "featureNames": ["temp", "hum", "windspeed", "days_since_2011", "season_FALL", "season_SPRING", "season_SUMMER", "season_WINTER", "yr_2011", "yr_2012", "mnth_APR", "mnth_AUG", "mnth_DEC", "mnth_FEB", "mnth_JAN", "mnth_JUL", "mnth_JUN", "mnth_MAR", "mnth_MAY", "mnth_NOV", "mnth_OCT", "mnth_SEP", "holiday_HOLIDAY", "holiday_NO HOLIDAY", "weekday_FRI", "weekday_MON", "weekday_SAT", "weekday_SUN", "weekday_THU", "weekday_TUE", "weekday_WED", "workingday_NO WORKING DAY", "workingday_WORKING DAY", "weathersit_GOOD", "weathersit_MISTY", "weathersit_RAIN/SNOW/STORM"], "explanations": [{"outValue": 7319.6357421875, "simIndex": 24.0, "features": {"0": {"effect": 909.6157117279755, "value": 19.416651}, "1": {"effect": 294.9913591033539, "value": 54.9167}, "2": {"effect": 45.097664677571856, "value": 12.499654}, "3": {"effect": 1277.8783907454633, "value": 518.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": 0.0, "value": 1.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 0.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": 0.0, "value": 0.0}, "14": {"effect": 0.0, "value": 0.0}, "15": {"effect": 0.0, "value": 0.0}, "16": {"effect": 0.0, "value": 1.0}, "17": {"effect": 0.0, "value": 0.0}, "18": {"effect": 0.0, "value": 0.0}, "19": {"effect": 0.0, "value": 0.0}, "20": {"effect": 0.0, "value": 0.0}, "21": {"effect": 0.0, "value": 0.0}, "22": {"effect": 1.0549084268637898, "value": 0.0}, "23": {"effect": 0.0, "value": 1.0}, "24": {"effect": 0.0, "value": 0.0}, "25": {"effect": -0.5125939953643694, "value": 0.0}, "26": {"effect": 138.04513550872826, "value": 1.0}, "27": {"effect": 24.049363490856194, "value": 0.0}, "28": {"effect": 0.0, "value": 0.0}, "29": {"effect": 0.0, "value": 0.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 1.0}, "32": {"effect": 0.0, "value": 0.0}, "33": {"effect": 128.97261990732886, "value": 1.0}, "34": {"effect": 0.0, "value": 0.0}, "35": {"effect": 20.454360663641637, "value": 0.0}}}, {"outValue": 2466.937744140625, "simIndex": 81.0, "features": {"0": {"effect": -886.1543450973018, "value": 9.533021000000002}, "1": {"effect": -212.8023783704017, "value": 71.6087}, "2": {"effect": -359.28387668073697, "value": 23.39171}, "3": {"effect": -370.6912960045224, "value": 381.0}, "4": {"effect": 0.0, "value": 0.0}, "5": {"effect": 0.0, "value": 0.0}, "6": {"effect": 0.0, "value": 0.0}, "7": {"effect": 0.0, "value": 1.0}, "8": {"effect": 0.0, "value": 0.0}, "9": {"effect": 0.0, "value": 1.0}, "10": {"effect": 0.0, "value": 0.0}, "11": {"effect": 0.0, "value": 0.0}, "12": {"effect": 0.0, "value": 0.0}, "13": {"effect": 0.0, "value": 0.0}, "14": {"effect": 0.0, "value": 1.0}, "15": {"effect": 0.0, "value": 0.0}, "16": {"effect": 0.0, "value": 0.0}, "17": {"effect": 0.0, "value": 0.0}, "18": {"effect": 0.0, "value": 0.0}, "19": {"effect": 0.0, "value": 0.0}, "20": {"effect": 0.0, "value": 0.0}, "21": {"effect": -10.089096583401442, "value": 0.0}, "22": {"effect": 0.0, "value": 0.0}, "23": {"effect": 0.0, "value": 1.0}, "24": {"effect": 0.0, "value": 0.0}, "25": {"effect": 0.0, "value": 0.0}, "26": {"effect": -14.92375205559074, "value": 0.0}, "27": {"effect": 0.0, "value": 0.0}, "28": {"effect": 0.0, "value": 0.0}, "29": {"effect": 0.0, "value": 1.0}, "30": {"effect": 0.0, "value": 0.0}, "31": {"effect": 0.0, "value": 0.0}, "32": {"effect": 0.0, "value": 1.0}, "33": {"effect": -159.10633299850156, "value": 0.0}, "34": {"effect": 0.0, "value": 1.0}, "35": {"effect": 0.0, "value": 0.0}}}, {"outValue": 1820.7774658203125, "simIndex": 86.0, "features": {"0": {"effect": -1129.5973573615997, "value": 4.506089}, "1": {"effect": 215.83997993072023, "value": 31.4348}, "2": {"effect": -108.5988231 ...

# %% [markdown]
# ## 自己動手練習看看 - 解釋波士頓房價預測
# ### Explore the dataset - Boston house price
# #### Features
# - CRIM: 每個城鎮的人均犯罪率
# - ZN: 佔地 25000 平方英尺以上的住宅區域比例
# - INDUS: 每個城鎮非零售業的營業面積比例
# - CHAS: 是否靠近河邊
# - NOX: 一氧化氮濃度（ppm)
# - RM: 每個住宅的平均房間數
# - AGE: 1940 年前私有住宅的住房比率
# - DIS: 與五個波士頓工作地區的加權距離
# - RAD: 徑向公路的通達指數
# - TAX: 每 10000 美元的所需繳的財產稅
# - PTRATIO : 每個城鎮的師生比例
# - B: 黑人比例 (值為$1000\times(Bk-0.63)^2$)
# - LSTAT: 中下階級的比率
#
# #### Labels
# - price: 該城鎮房價的中間值

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
housing = load_boston()
X = pd.DataFrame(housing.data, columns=housing.feature_names)
y = pd.DataFrame(housing.target, columns=['price'])
pd.concat([X, y], axis=1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# #### 使用 Kernel SHAP 來解釋 Support Vector Regression (SVR) 模型
# 使用 shap 來解釋全局、局部
# - shap.summary_plot: 全局解釋
# - shap.force_plot: 局部解釋
